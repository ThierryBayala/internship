# %%
import json
from time import sleep
from flask import Flask
from normalizer import *
from kafka import KafkaConsumer, KafkaProducer
from langdetect import detect




def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        
        producer_instance.send(topic_name, key=key_bytes.lower(), value=value_bytes.lower())
        producer_instance.flush()
        print('Corpus published successfully.')
    except Exception as ex:
        print('Exception in publishing the Corpus')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'], api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer


def parse(tweet):
    title = str(tweet)
    rec = {}
    try:
        rec = {'tweet': title}

    except Exception as ex:
        print('Exception while parsing')
        print(str(ex))
    finally:
        return json.dumps(rec)
    

def text_generation(lisTweet):
    return '. '.join(lisTweet)
    

if __name__ == '__main__':
    print("===> Generating the corpus ...")
    print()
    reords_corpus=[]
    list_tweet=[]
    
    topic_name = 'normalized_tweet' 
    parsed_topic_name = 'corpus_tweet'
    
    consumer = KafkaConsumer(topic_name, auto_offset_reset='earliest',
                             bootstrap_servers=['localhost:9092'], api_version=(0, 10), consumer_timeout_ms=1000)
    
    for msg in consumer:
        record=json.loads(msg.value)
        text=record['tweet']
        
        try: 
            if detect(text)=='en':
                doc = nlp(text)
                list_tweet.append(text)
        except:
            pass
        #print(doc)
        sleep(3)
    #text=text_generation(list_tweet)
    for text in list_tweet:
        print(text)
    
    #reords_corpus.append(parse(text.strip()))
    
    if len(reords_corpus) > 0:
        producer = connect_kafka_producer()
        for rec in reords_corpus:
            publish_message(producer, parsed_topic_name, 'corpus', rec)
# Out:
# ===> Generating the corpus ...
#
# tell her bring i am pumped with the meningitis vaccine and ready kick some oh and i can see her rib. teacher dies with meningitis symptom government denies he had influenza. shot dpt hepatitis a and meningitis ugh. omg what a bunch of halfwit maybe they re immune to meningitis thru having no. yeah cause meningitis is not like contagious oh wait. a teacher died and they\'re all but he didn\'t have swine he had meningitis as if that is not even. headache back it is not meningitis if i only have symptom headache stiff neck i am confused so that count. i had severe strep throat and dehydration but they thought meningitis so spinal tapped me. no meningitis or swine flu sore neck clicking knee are just some sign of getting would chocolate still be the. accidentally dragged ween instead of wallflower into my player was wondering why wallflower were doing spinal meningitis me. meningitis strain confirmed by cdc. cdc confirm that ohio university student were infected with a strain of bacterial meningitis. jen\ blog meningitis and a hospital stay for. brave crawley meningitis victim meets leona lewis. just found that a 16yr old girl in fibion church here just died of meningitis kinda this morning about that praying for them. it is not i get paranoid about meningitis all the time. i have no idea what it is i am really paranoid that its meningitis. my neck has hurt for about day straight i wonder if i have meningitis hahahaha kidding mom. pls pray for chad my friend lisa hubby he is in the hospital and they think it is meningitis it is been day. i have a permanent mark on my arm from where i got a meningitis shot year ago needle are a trap. yup in term of most common picornavirus    it is cox a for foot hand cox b for heart echo for meningitis. i always figured spinal meningitis would get me turns clinical depression does it as well. probably have swine flu thing i am more afraid car crash meningitis shark attack tripping on a pebble small child gnats deal. was the other the meningitis that hurts like hell. quite a few nothing serious well i say that but i did have suspected meningitis once. meningitis in a baby linked to pet a paper in the journal of clinical microbiology described a case of. meningitis strain confirmed by the center for disease control and prevention has confirmed that the. now sporting snoopy spot for my yellow fever hepb and meningitis good go now. side of my jaw hurts and i have a very very slight fever meningitis pre coldplay reaction to. we have been mia meningitis and a hospital stay for our baby    read a summary. final diagnosis bacterial meningitis thankful have myle home and praying for those around the world who do not have hospital care. tx h. influenza meningitis. treatment b cell test predict who will get meningitis. cos there son died from meningitis and they could nt bear it so they jumped from beachyhead    twas there funral today and they. bellefontaine hospital submit anti- meningitis plan. charity cd in memory of thommy purbrook who died dec from meningitis whilst on a school trip to russia. eish ithute primary school in alex is hit by meningitis child hav past on already strength to their prayer to the. i have been injected with meningitis strand of i met a lovely couple at the bus stop who are on there way see. climate change blamed for measle outbreak in a meningitis epidemic that killed more than people si. not in class studying on 9th til hope meningitis lecture is worth going to. such a sad story couple who is son died from meningitis killed themselves due to their grief. my friend mom was very ill last wk viral meningitis super scary and wierd but she is better now i will pray for your. i once had a migraine so horrendous that i vomited multiple time good thing i did not know about viral meningitis back then. encephalitis is known as inflamation of the brain itself not the meningitis there is no known cure. info from mark wife getting a ct scan and spinal tap possible meningitis hope he gets s ...
# Corpus published successfully.
